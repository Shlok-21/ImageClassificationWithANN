# %% [markdown]
# # Objective: Forest vs Building Classification Using ANN

# %% [markdown]
# Steps:
# 1. Importing (or installing) Tenosrflow, Keras and other packages on your system
# 2. Loading your data from disk
# 3. Creating your training and testing splits
# 4. Data Preprocessing
# 5. Defining your tensorflow ANN model architecture
# 6. Compiling your tensorflow ANN model
# 7. Training your model on your training data
# 8. Evaluating your model on your test data
# 9. Generate Plots for accuracy and validation loss
# 10. Saving The train model
# 11. Making predictions using your trained tensorflow model

# %% [markdown]
# ### Step 1: Importing all the packages

# %%
# Import libraries and packages
import matplotlib as plt
import matplotlib.pyplot as plt
# %matplotlib inline
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix , accuracy_score, classification_report
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import SGD
from imutils import paths
import matplotlib.pyplot as plt
import numpy as np
import random
import pickle
import cv2
import os
import time   # time1 = time.time(); print('Time taken: {:.1f} seconds'.format(time.time() - time1))
import warnings
from tqdm import tqdm_notebook as tqdm
import itertools

warnings.filterwarnings("ignore")
SEED = 42   # set random seed

# %% [markdown]
# ### Step 2: Loading your data from disk for training

# %%
# mount google drive to collab notebook
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# change working DIR 
import os 
os.chdir("/content/drive/MyDrive/PGAA08_Deep_Learning/Code Files/1. Image Classification using ANN")

# %%
# !dir
# Out:
# Class_Demo_ANN.ipynb  Final_ANN.html   Project.ipynb
# dataset		      Final_ANN.ipynb  test_examples
# dataset.rar	      model_ANN.h5     test_examples.rar

# %%
# Extract dataset.rar file
# !pip install patool

# %%
# import patoolib
# patoolib.extract_archive("dataset.rar")

# %%
# patoolib.extract_archive("test_examples.rar")

# %%
# initialize the data and labels
print("[INFO] loading images...")
time1 = time.time()   # to measure time taken
data = []
labels = []

classes = ["Forest", "Buildings"]

# grab the image paths and randomly shuffle them
imagePaths = sorted(list(paths.list_images('dataset')))   # data folder with 2 categorical folders
random.seed(SEED)
random.shuffle(imagePaths)

# progress bar 
with tqdm(total=len(imagePaths)) as pbar:
    
    # loop over the input images
    for imagePath in imagePaths:
        # load the image, resize the image to be 32x32 pixels (ignoring aspect ratio), 
        # flatten the 32x32x3=3072 pixel image into a list, and store the image in the data list
        image = cv2.imread(imagePath)
        image = cv2.resize(image, (32, 32)).flatten()
        data.append(image)

        # extract the class label from the image path and update the labels list
        label = imagePath.split(os.path.sep)[-2]
        
        label = 1 if label == "Buildings" else 0
        labels.append(label)
        
        # update the progressbar
        pbar.update(1)

# scale the raw pixel intensities to the range [0, 1]
data = np.array(data, dtype="float") / 255.0
labels = np.array(labels)

print('Time taken: {:.1f} seconds'.format(time.time() - time1))   # to measure time taken
print("done")
# Out:
# [INFO] loading images...
#   0%|          | 0/883 [00:00<?, ?it/s]
# Time taken: 111.3 seconds
# done

# %%
a = ["dev", 24, True]

# %%
a
# Out:
# ['dev', 24, True]

# %%
b = np.array([24, True, 7.9, 1+2j, "dev"])

# %%
b
# Out:
# array(['24', 'True', '7.9', '(1+2j)', 'dev'], dtype='<U64')

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print("Total Images: ", len(data))

# %%
# sample data for first image
print("sample image: {}".format(data[0]))
print("no of features/pixels values: {}".format(len(data[0]))) # 32x32x3=3072
print("label: {}".format(classes[labels[0]]))
# Out:
# sample image: [0.31764706 0.29803922 0.28627451 ... 0.74117647 0.58823529 0.4627451 ]
# no of features/pixels values: 3072
# label: Forest

# %% [markdown]
# ### Step 3: Creating your training and testing splits

# %%
# partition the data into 80% training and 20% validation
(trainX, testX, trainY, testY) = train_test_split(data, labels, test_size=0.2, random_state=SEED)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
trainX.shape
# Out:
# (706, 3072)

# %%
trainY.shape
# Out:
# (706,)

# %%
testX.shape
# Out:
# (177, 3072)

# %%
testY.shape
# Out:
# (177,)

# %%
trainX

# %%
trainY

# %%
type(trainY)
# Out:
# numpy.ndarray

# %%
testY

# %% [markdown]
# ### Step 4: Data Preprocessing

# %%
# convert the labels from integers/categories to vectors 

trainY = to_categorical(trainY, num_classes=2)   # fit_transform = find all unique class labels + transform into one-hot encoded labels
testY = to_categorical(testY, num_classes=2)     # transform = perform the one-hot encoding (unique class labels already found)

# [0,1] Buildings
# [1,0] Forest

# %%
sample_image = (trainX[5] * 255).astype("int")

# %%
plt.imshow(sample_image.reshape(32,32,3))

# %%
trainY[5]   # [0,1] means buildings [1,0] means forest
# Out:
# array([0., 1.], dtype=float32)

# %% [markdown]
# ### Step 5:  Define the architecture for ANN MODEL

# %%
# define the 3072-1024-512-1 architecture using Keras

model = Sequential()   

# input layer 3072 as there are 32x32x3=3072 pixels in a flattened input image
# first hidden layer has 1024 nodes
model.add(Dense(units= 1024, input_shape=(3072,), kernel_initializer = 'uniform', activation="relu"))  

# # dropout for second layer 
model.add(Dropout(0.4))

# second hidden layer has 512 nodes
model.add(Dense(units=512, kernel_initializer='uniform', activation="relu"))                         

 # output layer with number of possible class labels
model.add(Dense(units=2,kernel_initializer='uniform', activation="softmax"))

# %% [markdown]
# ## Compile Model

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Step 6:  Compiling your tensorflow ANN model

# %%
# initialize our initial learning rate and # of epochs to train for
INIT_LR = 0.01
EPOCHS = 50
 
# compile the model using SGD as our optimizer and categorical cross-entropy loss
# (you'll want to use binary_crossentropy for 2-class classification)
print("[INFO] compiling network network...")
opt = SGD(lr=INIT_LR)   # Stochastic Gradient Descent (SGD) optimizer
model.compile(loss="binary_crossentropy", optimizer=opt, metrics=["accuracy"])
# Out:
# [INFO] compiling network network...

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 1024)              3146752
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_4 (Dense)             (None, 512)               524800
#
#  dense_5 (Dense)             (None, 2)                 1026
#
# =================================================================
# Total params: 3,672,578
# Trainable params: 3,672,578
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Step 7: Training your model on your training data

# %% [markdown]
# #### Fit (ie, Train) model

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# train the neural network on training data set
# batch_size (32) controls the size of each group of data to pass through the network. 

time1 = time.time()   # to measure time taken
H = model.fit(trainX, trainY, validation_data=(testX, testY), epochs=EPOCHS, batch_size=32)
print('Time taken: {:.1f} seconds'.format(time.time() - time1))   # to measure time taken
# Out:
# Epoch 1/50
# 23/23 [==============================] - 1s 14ms/step - loss: 0.6585 - accuracy: 0.5510 - val_loss: 0.6492 - val_accuracy: 0.5367
# Epoch 2/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.6297 - accuracy: 0.5595 - val_loss: 0.6355 - val_accuracy: 0.5367
# Epoch 3/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.6213 - accuracy: 0.5666 - val_loss: 0.6197 - val_accuracy: 0.5367
# Epoch 4/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.6051 - accuracy: 0.5977 - val_loss: 0.5830 - val_accuracy: 0.6384
# Epoch 5/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5790 - accuracy: 0.6671 - val_loss: 0.5696 - val_accuracy: 0.7458
# Epoch 6/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5683 - accuracy: 0.6941 - val_loss: 0.5444 - val_accuracy: 0.7175
# Epoch 7/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5491 - accuracy: 0.7337 - val_loss: 0.5578 - val_accuracy: 0.6271
# Epoch 8/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5370 - accuracy: 0.7181 - val_loss: 0.5022 - val_accuracy: 0.8249
# Epoch 9/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5076 - accuracy: 0.7805 - val_loss: 0.5202 - val_accuracy: 0.6949
# Epoch 10/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5007 - accuracy: 0.7691 - val_loss: 0.4757 - val_accuracy: 0.7401
# Epoch 11/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4822 - accuracy: 0.7904 - val_loss: 0.4682 - val_accuracy: 0.7345
# Epoch 12/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4613 - accuracy: 0.8074 - val_loss: 0.4284 - val_accuracy: 0.8192
# Epoch 13/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4461 - accuracy: 0.8130 - val_loss: 0.4682 - val_accuracy: 0.7288
# Epoch 14/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4530 - accuracy: 0.8017 - val_loss: 0.4093 - val_accuracy: 0.8701
# Epoch 15/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4403 - accuracy: 0.8116 - val_loss: 0.3883 - val_accuracy: 0.8644
# Epoch 16/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4259 - accuracy: 0.8187 - val_loss: 0.3847 - val_accuracy: 0.8362
# Epoch 17/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4129 - accuracy: 0.8244 - val_loss: 0.3715 - val_accuracy: 0.8757
# Epoch 18/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3919 - accuracy: 0.8470 - val_loss: 0.3769 - val_accuracy: 0.8757
# Epoch 19/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.3966 - accuracy: 0.8329 - val_loss: 0.3642 - val_accuracy: 0.8870
# Epoch 20/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.3872 - accuracy: 0.8428 - val_loss: 0.4004 - val_accuracy: 0.8305
# Epoch 21/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.3834 - accuracy: 0.8612 - val_loss: 0.3813 - val_accuracy: 0.8588
# Epoch 22/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.3618 - accuracy: 0.8456 - val_loss: 0.3731 - val_accuracy: 0.8701
# Epoch 23/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.3746 - accuracy: 0.8598 - val_loss: 0.3637 - val_accuracy: 0.8362
# Epoch 24/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.3605 - accuracy: 0.8499 - val_loss: 0.3371 - val_accuracy: 0.8814
# Epoch 25/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.3418 - accuracy: 0.8839 - val_loss: 0.3354 - val_accuracy: 0.8588
# Epoch 26/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.3500 - accuracy: 0.8555 - val_loss: 0.3823 - val_accuracy: 0.8418
# Epoch 27/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.3406 - accuracy: 0.8867 - val_loss: 0.3339 - val_accuracy: 0.8588
# Epoch 28/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.3222 - accuracy: 0.8711 - val_loss: 0.3467 - val_accuracy: 0.8418
# Epoch 29/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.3212 - accuracy: 0.8725 - val_loss: 1.4822 - val_accuracy: 0.4802
# Epoch 30/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.3830 - accuracy: 0.8442 - val_loss: 0.3421 - val_accuracy: 0.8814
# Epoch 31/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.3192 - accuracy: 0.8725 - val_loss: 0.3517 - val_accuracy: 0.8249
# Epoch 32/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.3088 - accuracy: 0.8739 - val_loss: 0.3345 - val_accuracy: 0.8644
# Epoch 33/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3151 - accuracy: 0.8725 - val_loss: 0.3231 - val_accuracy: 0.8701
# Epoch 34/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.3066 - accuracy: 0.8867 - val_loss: 0.3380 - val_accuracy: 0.8588
# Epoch 35/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2999 - accuracy: 0.8768 - val_loss: 0.4064 - val_accuracy: 0.7966
# Epoch 36/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.2966 - accuracy: 0.8881 - val_loss: 0.3217 - val_accuracy: 0.8701
# Epoch 37/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2948 - accuracy: 0.8768 - val_loss: 0.3460 - val_accuracy: 0.8701
# Epoch 38/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2678 - accuracy: 0.9023 - val_loss: 0.3354 - val_accuracy: 0.8701
# Epoch 39/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2645 - accuracy: 0.9037 - val_loss: 0.3376 - val_accuracy: 0.8531
# Epoch 40/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2705 - accuracy: 0.8924 - val_loss: 0.3191 - val_accuracy: 0.8588
# Epoch 41/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2649 - accuracy: 0.9037 - val_loss: 0.3603 - val_accuracy: 0.8418
# Epoch 42/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2588 - accuracy: 0.8952 - val_loss: 0.3300 - val_accuracy: 0.8644
# Epoch 43/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2623 - accuracy: 0.8966 - val_loss: 0.4748 - val_accuracy: 0.7571
# Epoch 44/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2480 - accuracy: 0.9136 - val_loss: 0.3605 - val_accuracy: 0.8305
# Epoch 45/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2416 - accuracy: 0.9235 - val_loss: 0.4042 - val_accuracy: 0.8192
# Epoch 46/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2541 - accuracy: 0.9008 - val_loss: 1.0412 - val_accuracy: 0.5819
# Epoch 47/50
# 23/23 [==============================] - 0s 6ms/step - loss: 0.2706 - accuracy: 0.9051 - val_loss: 1.1666 - val_accuracy: 0.5537
# Epoch 48/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2809 - accuracy: 0.9065 - val_loss: 1.1211 - val_accuracy: 0.5424
# Epoch 49/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2929 - accuracy: 0.8881 - val_loss: 0.3140 - val_accuracy: 0.8701
# Epoch 50/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2389 - accuracy: 0.9108 - val_loss: 0.5912 - val_accuracy: 0.7627
# Time taken: 10.7 seconds

# %% [markdown]
# ### Step 8: Evaluating your model on your test data

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# evaluate the network
print("[INFO] evaluating network...")
pred_prob = model.predict(testX, batch_size=32)
# Out:
# [INFO] evaluating network...

# %%
1.30915156e-04
# Out:
# 0.000130915156

# %%
9.99869108e-01
# Out:
# 0.999869108

# %%
pred_prob
# Out:
# array([[5.33350430e-06, 9.99994636e-01],
#        [9.06520963e-01, 9.34789851e-02],
#        [1.44079172e-06, 9.99998569e-01],
#        [9.96143579e-01, 3.85641493e-03],
#        [7.40257561e-01, 2.59742498e-01],
#        [9.99957561e-01, 4.24362224e-05],
#        [1.18553899e-05, 9.99988198e-01],
#        [7.95072556e-01, 2.04927444e-01],
#        [8.42481375e-01, 1.57518625e-01],
#        [9.99999285e-01, 6.81719655e-07],
#        [2.69250516e-02, 9.73074973e-01],
#        [2.32848688e-03, 9.97671545e-01],
#        [7.29070371e-06, 9.99992728e-01],
#        [3.75153683e-02, 9.62484658e-01],
#        [5.12350071e-03, 9.94876564e-01],
#        [3.23406309e-01, 6.76593721e-01],
#        [1.03291648e-04, 9.99896646e-01],
#        [1.21992542e-07, 9.99999881e-01],
#        [9.99831200e-01, 1.68823637e-04],
#        [7.25471025e-08, 9.99999881e-01],
#        [3.47216678e-06, 9.99996543e-01],
#        [2.41116673e-01, 7.58883297e-01],
#        [8.06308985e-01, 1.93691030e-01],
#        [1.88200079e-06, 9.99998093e-01],
#        [1.57253865e-07, 9.99999881e-01],
#        [5.64045250e-01, 4.35954809e-01],
#        [5.91529250e-01, 4.08470750e-01],
#        [6.94357141e-08, 9.99999881e-01],
#        [9.84598279e-01, 1.54016642e-02],
#        [5.71390707e-03, 9.94286120e-01],
#        [9.96987164e-01, 3.01287044e-03],
#        [2.82028364e-03, 9.97179747e-01],
#        [9.99708831e-01, 2.91139615e-04],
#        [9.85659599e-01, 1.43403262e-02],
#        [9.85547662e-01, 1.44523624e-02],
#        [5.89533709e-03, 9.94104683e-01],
#        [5.11396714e-02, 9.48860288e-01],
#        [9.73171651e-01, 2.68283412e-02],
#        [6.17392404e-09, 1.00000000e+00],
#        [2.06010918e-05, 9.99979377e-01],
#        [3.98226148e-05, 9.99960184e-01],
#        [1.53795622e-06, 9.99998450e-01],
#        [1.34673007e-02, 9.86532688e-01],
#        [6.35406025e-07, 9.99999404e-01],
#        [3.29912543e-01, 6.70087457e-01],
#        [2.84778234e-02, 9.71522152e-01],
#        [8.36301479e-04, 9.99163747e-01],
#        [3.71013584e-06, 9.99996305e-01],
#        [5.55414532e-04, 9.99444544e-01],
#        [2.99280891e-05, 9.99970078e-01],
#        [3.14340905e-05, 9.99968529e-01],
#        [9.03849304e-01, 9.61507335e-02],
#        [8.31457237e-06, 9.99991655e-01],
#        [8.53406250e-01, 1.46593794e-01],
#        [2.79925189e-05, 9.99971986e-01],
#        [9.99845982e-01, 1.54031397e-04],
#        [6.84319801e-09, 1.00000000e+00],
#        [5.39397122e-03, 9.94606078e-01],
#        [4.31308091e-01, 5.68691909e-01],
#        [1.05777399e-04, 9.99894261e-01],
#        [1.44264895e-05, 9.99985576e-01],
#        [9.99924541e-01, 7.53989007e-05],
#        [8.54233622e-06, 9.99991417e-01],
#        [9.34122860e-01, 6.58771470e-02],
#        [1.03074429e-03, 9.98969316e-01],
#        [1.38871580e-01, 8.61128390e-01],
#        [2.09298849e-01, 7.90701151e-01],
#        [5.32652318e-01, 4.67347652e-01],
#        [5.75754939e-06, 9.99994278e-01],
#        [1.01715922e-02, 9.89828467e-01],
#        [9.99956369e-01, 4.36737755e-05],
#        [1.55899242e-01, 8.44100833e-01],
#        [1.77661285e-01, 8.22338700e-01],
#        [6.57019257e-07, 9.99999285e-01],
#        [6.16209954e-03, 9.93837893e-01],
#        [9.62913236e-06, 9.99990344e-01],
#        [9.09424722e-01, 9.05752778e-02],
#        [9.85995710e-01, 1.40042724e-02],
#        [1.28612257e-07, 9.99999881e-01],
#        [2.65636658e-07, 9.99999762e-01],
#        [4.30426095e-03, 9.95695710e-01],
#        [2.07895599e-02, 9.79210436e-01],
#        [2.05387114e-05, 9.99979496e-01],
#        [9.99971151e-01, 2.88073497e-05],
#        [1.54092655e-01, 8.45907390e-01],
#        [9.90163624e-01, 9.83634591e-03],
#        [1.25784494e-09, 1.00000000e+00],
#        [7.51262769e-06, 9.99992490e-01],
#        [4.07302342e-02, 9.59269762e-01],
#        [5.26090625e-05, 9.99947429e-01],
#        [1.41163126e-01, 8.58836830e-01],
#        [1.13871899e-07, 9.99999881e-01],
#        [3.83633143e-08, 1.00000000e+00],
#        [6.97696447e-01, 3.02303582e-01],
#        [3.87806322e-05, 9.99961257e-01],
#        [8.64626374e-04, 9.99135435e-01],
#        [2.95661430e-05, 9.99970436e-01],
#        [1.37000280e-02, 9.86300051e-01],
#        [3.94211793e-06, 9.99996066e-01],
#        [1.35463238e-01, 8.64536762e-01],
#        [9.97195601e-01, 2.80436780e-03],
#        [3.57878879e-02, 9.64212120e-01],
#        [9.57599582e-07, 9.99999046e-01],
#        [9.99905109e-01, 9.48878442e-05],
#        [1.90200403e-01, 8.09799612e-01],
#        [3.77460111e-07, 9.99999642e-01],
#        [9.05132947e-06, 9.99990940e-01],
#        [5.42628504e-06, 9.99994516e-01],
#        [9.01277781e-01, 9.87221673e-02],
#        [4.17072761e-06, 9.99995828e-01],
#        [6.16919016e-04, 9.99383092e-01],
#        [9.99643087e-01, 3.56900535e-04],
#        [9.98002470e-01, 1.99758261e-03],
#        [5.92614412e-02, 9.40738559e-01],
#        [9.41343367e-01, 5.86565994e-02],
#        [1.14771258e-03, 9.98852253e-01],
#        [7.91381180e-01, 2.08618820e-01],
#        [4.84276484e-07, 9.99999523e-01],
#        [1.14049501e-04, 9.99885917e-01],
#        [2.08064023e-07, 9.99999762e-01],
#        [6.56108838e-08, 9.99999881e-01],
#        [1.29710719e-01, 8.70289326e-01],
#        [7.10458517e-06, 9.99992847e-01],
#        [2.95215978e-05, 9.99970436e-01],
#        [4.25319193e-08, 1.00000000e+00],
#        [4.25925173e-05, 9.99957442e-01],
#        [8.19316506e-01, 1.80683464e-01],
#        [3.00358534e-02, 9.69964147e-01],
#        [1.96018268e-09, 1.00000000e+00],
#        [6.59104553e-05, 9.99934077e-01],
#        [4.96994355e-04, 9.99503016e-01],
#        [1.56547162e-06, 9.99998450e-01],
#        [9.37614706e-04, 9.99062359e-01],
#        [9.44281453e-08, 9.99999881e-01],
#        [9.99990344e-01, 9.60884063e-06],
#        [9.89472091e-01, 1.05278539e-02],
#        [6.01362623e-03, 9.93986368e-01],
#        [4.72182661e-01, 5.27817369e-01],
#        [1.46316085e-03, 9.98536825e-01],
#        [8.17631207e-09, 1.00000000e+00],
#        [9.93429101e-04, 9.99006569e-01],
#        [1.22267781e-02, 9.87773240e-01],
#        [2.48761605e-02, 9.75123823e-01],
#        [5.36602727e-08, 1.00000000e+00],
#        [4.36477330e-06, 9.99995589e-01],
#        [1.69291487e-03, 9.98307109e-01],
#        [3.44381260e-06, 9.99996543e-01],
#        [1.15444652e-06, 9.99998808e-01],
#        [7.73692932e-08, 9.99999881e-01],
#        [9.34882555e-03, 9.90651131e-01],
#        [9.56768692e-01, 4.32312861e-02],
#        [1.00000000e+00, 1.88426359e-08],
#        [9.92200434e-01, 7.79963611e-03],
#        [1.39115008e-09, 1.00000000e+00],
#        [1.59596475e-05, 9.99984026e-01],
#        [4.59101889e-03, 9.95408952e-01],
#        [2.68482807e-04, 9.99731481e-01],
#        [6.21421862e-07, 9.99999404e-01],
#        [1.59662345e-03, 9.98403370e-01],
#        [2.99356203e-03, 9.97006476e-01],
#        [1.14016461e-06, 9.99998808e-01],
#        [1.55925378e-02, 9.84407544e-01],
#        [9.95899856e-01, 4.10007872e-03],
#        [9.36055854e-02, 9.06394422e-01],
#        [1.79760595e-04, 9.99820292e-01],
#        [8.95669316e-09, 1.00000000e+00],
#        [6.63914010e-02, 9.33608651e-01],
#        [6.34599985e-07, 9.99999404e-01],
#        [5.67247724e-08, 1.00000000e+00],
#        [9.99996305e-01, 3.67261600e-06],
#        [2.94489618e-02, 9.70551074e-01],
#        [1.16549106e-03, 9.98834550e-01],
#        [4.88537808e-05, 9.99951124e-01],
#        [4.94685531e-01, 5.05314469e-01],
#        [1.94863300e-04, 9.99805152e-01],
#        [9.74588872e-08, 9.99999881e-01],
#        [2.39704650e-06, 9.99997616e-01]], dtype=float32)

# %%
9.25910056e-01

# %%
9.6146774e-01

# %%
# testY

# %% [markdown]
# ### Convert testY and y_pred into 1's and 0 for classification report

# %%
# Note: buildings -> 1 and forest -> 0

# %%
test_y = [ np.argmax(i)  for i in testY]
pred_y = [ np.argmax(i)  for i in pred_prob]

# %%
# test_y

# %%
pred_y

# %%
def plot_confusion_metrix(y_true, y_pred,classes,
                         normalize=False,
                         title='Confusion Matrix',
                         cmap=plt.cm.Blues):
    """
    Objective
    ----------
    plot confussion matrix, classification report and accuracy score
    
    parameters
    ----------
    y_true : array-like of shape (n_samples,)
        Ground truth (correct) target values.

    y_pred : array-like of shape (n_samples,)
        Estimated targets as returned by a classifier.
    
    classes : list
        List of labels to index the matrix
        
    title : title for matrix
    cmap : colormap for matrix 
    
    returns 
    ----------
   all accruacy matrix 
    """
    
    
    cm = confusion_matrix(y_true,y_pred)
    
    
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized Confusion Matrix")
    else:
        print("Confusion Matrix, Without Normalisation")

    
    plt.imshow(cm, interpolation='nearest',cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks,classes,rotation=35)
    plt.yticks(tick_marks,classes)
    
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() /2.
    
    for i , j in itertools.product(range(cm.shape[0]), range(cm.shape[0])):
        plt.text(j, i, format(cm[i,j], fmt),
                 horizontalalignment='center',
                 color='white' if cm[i, j] > thresh else 'black')
    
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    # plt.tight_layout()
    
    plt.show()
    
    print("-----------------------------------------------------")
    print('Classification report')
    print(classification_report(y_true,y_pred))
    
    print("-----------------------------------------------------")
    acc= accuracy_score(y_true,y_pred)
    print("Accuracy of the model: ", acc)

# %%
plot_confusion_metrix(test_y, pred_y,classes=["Forest: 0","Buildings: 1"])
# Out:
# Confusion Matrix, Without Normalisation
# -----------------------------------------------------
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.95      0.51      0.67        82
#            1       0.70      0.98      0.82        95
#
#     accuracy                           0.76       177
#    macro avg       0.83      0.75      0.74       177
# weighted avg       0.82      0.76      0.75       177
#
# -----------------------------------------------------
# Accuracy of the model:  0.7627118644067796

# %% [markdown]
# ### Step 9: Generate Plots for acc and val

# %%
# plot the training and validation loss
N = np.arange(0, EPOCHS)
plt.style.use("ggplot")
plt.figure(figsize = [10,8])
plt.plot(N, H.history["loss"], label="train_loss")
plt.plot(N, H.history["val_loss"], label="val_loss")
plt.title("ANN: Training & Validation Loss")
plt.xlabel("Epoch #", weight="bold")
plt.ylabel("Loss", weight="bold")
plt.legend()
plt.show()

# %%
# plot the training and validation accuracy
N = np.arange(0, EPOCHS)
plt.style.use("ggplot")
plt.figure(figsize = [10,8])
plt.plot(N, H.history["accuracy"], label="train_acc")
plt.plot(N, H.history["val_accuracy"], label="val_acc")
plt.title("ANN: Training and Validation Accuracy")
plt.xlabel("Epoch #", weight="bold")
plt.ylabel("Accuracy", weight="bold")
plt.legend()
plt.show()

# %%
# accuracy = 88%

# %% [markdown]
# ### Step 10: Saving the train model

# %%
model.summary()

# %%
# save the model and label binarizer to disk
print("[INFO] serializing network and label binarizer...")
model.save('model_ANN.h5')
# Out:
# [INFO] serializing network and label binarizer...

# %% [markdown]
# ### Step 11: Making predictions using your trained tensorflow model

# %%
# import the necessary packages
from tensorflow.keras.models import load_model
import pickle
import cv2
import imutils
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# # load the model 
# print("[INFO] loading network and...")
model2 = load_model("model_ANN.h5")

# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.8.0'

# %%
def display_img(img):
    fig = plt.figure(figsize=(12,10))
    plt.grid(b=None)
    ax = fig.add_subplot(111)
    ax.imshow(img)

# %%
# load the input image and resize it to the target spatial dimensions
width = 32
height = 32

# grab the image paths and randomly shuffle them
testImagePaths = sorted(list(paths.list_images('test_examples')))   # test data folder with random images


# progress bar 
with tqdm(total=len(testImagePaths)) as pbar:
    
    for imagePath in testImagePaths:
        image = cv2.imread(imagePath)
        output = image.copy()
        image = cv2.resize(image, (width, height))

        # scale the pixel values to [0, 1]
        image = image.astype("float") / 255.0

        # for a simple fully-connected network, flatten the image
        image = image.flatten()
        image = image.reshape((1, image.shape[0]))


        # make a prediction on the image
        preds = model.predict(image)

        # find the class label index with the largest corresponding probability
        i = preds.argmax(axis=1)[0]
        label = classes[i]
        
        label = "{}: {:.2f}%".format(label, preds[0][i] * 100)

        
        output = imutils.resize(output, width=400)
        cv2.putText(output, label, (10, 25),  cv2.FONT_HERSHEY_SIMPLEX,
            0.7, (0, 255, 78), 2)
        
        # convert img to rgb format and display in noteboo
        img = cv2.cvtColor(output, cv2.COLOR_BGR2RGB)
        display_img(img)

#         print("############################")
#         print("image: {}".format(os.path.split(imagePath)[-1]))
#         print("predicted label: {}".format(label))
#         print("Confidence: {}".format(preds[0][i]))
        
        pbar.update(1)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ## Deployment

# %%
# !pip install gradio

# %%
import gradio as gr

# %%
def predict_image(image):
    
    image = cv2.resize(image, (32, 32))

    # scale the pixel values to [0, 1]
    image = image.astype("float") / 255.0

    # for a simple fully-connected network, flatten the image
    image = image.flatten()
    image = image.reshape((1, image.shape[0]))




    # make a prediction on the image
    preds = model.predict(image).flatten()
    result = dict()
    result["Forest"] = round(float(list(preds)[0]), 3)
    result["Buildings"] = round(float(list(preds)[1]), 3)
    print(result)
    
    return result

im = gr.inputs.Image(shape=(32,32))
label = gr.outputs.Label(num_top_classes=2)

gr.Interface(fn=predict_image, inputs=im, outputs=label, capture_session=True, title="ANN Demo").launch(share=True)
# Out:
# Colab notebook detected. To show errors in colab notebook, set `debug=True` in `launch()`
# Running on public URL: https://50353.gradio.app
#
# This share link expires in 72 hours. For free permanent hosting, check out Spaces (https://huggingface.co/spaces)
#         <iframe
#             width="900"
#             height="500"
#             src="https://50353.gradio.app"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# (<fastapi.applications.FastAPI at 0x7fc7215a8c10>,
#  'http://127.0.0.1:7860/',
#  'https://50353.gradio.app')
